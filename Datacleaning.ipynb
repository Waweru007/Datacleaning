# %%
import pandas as pd
df=pd.read_excel("Dataset8.xlsx")
import numpy as np
from scipy import stats

# %%
df=df.drop(columns=['Unnamed: 0','Harsolie','Benzeen','Roetolie','CD.CBO','MTBE','Kraakbenzine','BKM'])

# %%
# df=df.drop(columns=['Niveau T701','Flow Benzine'])
# df.describe()
df=pd.read_excel("/home/forecast/Desktop/df.xlsx")

# %%
for col in df.columns: 
    print(col)
# Out:
# VRU.Dampinlaat
# Temperatuur Benzine
# Flow Benzine
# Buitentemperatuur
# Niveau T701
# KWS.Inlaat
# Benzeen.Inlaat

# %%
from scipy import stats
dfclean=df[(np.abs(stats.zscore(df)) < 3).all(axis=1)]

# %%
df=pd.read_excel("/home/forecast/Desktop/df2.xlsx")

# %%
df=df.dropna()

# %%
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
df.isna().sum()
# Out:
# Harsolie               0
# Benzeen                0
# Roetolie               0
# CD.CBO                 0
# MTBE                   0
# Kraakbenzine           0
# BKM                    0
# VRU.Dampinlaat         0
# Temperatuur Benzine    0
# Flow Benzine           0
# Buitentemperatuur      0
# Niveau T701            0
# KWS.Inlaat             0
# Benzeen.Inlaat         0
# dtype: int64

# %%
# df.isna().sum() 
dfclean.describe()
# Out:
#             Harsolie        Benzeen       Roetolie        CD.CBO  \
# count  353231.000000  353231.000000  353231.000000  353231.00000
# mean        0.003680      28.982786      13.422720      13.11502
# std         0.236975      69.228859      34.266643      34.56305
# min         0.000000       0.000000       0.000000       0.00000
# 25%         0.000000       0.000000       0.000000       0.00000
# 50%         0.000000       0.000000       0.000000       0.00000
# 75%         0.000000       0.000000       0.000000       0.00000
# max        19.954000     250.987000     163.299000     140.89300
#
#                 MTBE   Kraakbenzine            BKM  VRU.Dampinlaat  \
# count  353231.000000  353231.000000  353231.000000   353231.000000
# mean        4.892608      22.917270       0.287884      182.804494
# std        22.372409      66.081679       2.852447       91.763735
# min         0.000000       0.000000     -45.302000        0.568000
# ...

# %%
y=dfclean['KWS.Inlaat']
X=dfclean.drop(['KWS.Inlaat'], axis=1)

# %%
regressor = LinearRegression()  
model=regressor.fit(X, y)

# %%
print(regressor)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
df.describe()
# Out:
#             Harsolie        Benzeen       Roetolie         CD.CBO  \
# count  438948.000000  438948.000000  438948.000000  438948.000000
# mean        1.742912      28.068180      17.744956      16.637665
# std        17.477638      74.339676      48.888674      41.420562
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max       196.781000   19069.891000     720.000000     204.898000
#
#                 MTBE   Kraakbenzine            BKM  VRU.Dampinlaat  \
# count  438948.000000  438948.000000  438948.000000   438948.000000
# mean       16.482388      37.677544       0.008379      203.240062
# std        58.536155      89.019694      15.106109      121.542941
# min         0.000000       0.000000    -248.533000        0.568000
# ...

# %%
import statsmodels.formula.api as sm
model = sm.ols(formula='y ~ X', data=dfclean)

# %%
fitted1 = model.fit()
fitted1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.370
# Model:                            OLS   Adj. R-squared:                  0.370
# Method:                 Least Squares   F-statistic:                 1.593e+04
# Date:                Mon, 13 Apr 2020   Prob (F-statistic):               0.00
# Time:                        18:02:28   Log-Likelihood:            -3.7367e+06
# No. Observations:              353231   AIC:                         7.473e+06
# Df Residuals:                  353217   BIC:                         7.474e+06
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.423e+04    118.563    120.019      0.000     1.4e+04    1.45e+04
# ...

# %%
dfclean.to_excel("/home/forecast/Desktop/clean8.xlsx")

# %%
df=pd.read_excel("/home/forecast/Desktop/clean8.xlsx")

# %%
dfclean.describe()
# Out:
#             Harsolie        Benzeen       Roetolie        CD.CBO  \
# count  353231.000000  353231.000000  353231.000000  353231.00000
# mean        0.003680      28.982786      13.422720      13.11502
# std         0.236975      69.228859      34.266643      34.56305
# min         0.000000       0.000000       0.000000       0.00000
# 25%         0.000000       0.000000       0.000000       0.00000
# 50%         0.000000       0.000000       0.000000       0.00000
# 75%         0.000000       0.000000       0.000000       0.00000
# max        19.954000     250.987000     163.299000     140.89300
#
#                 MTBE   Kraakbenzine            BKM  VRU.Dampinlaat  \
# count  353231.000000  353231.000000  353231.000000   353231.000000
# mean        4.892608      22.917270       0.287884      182.804494
# std        22.372409      66.081679       2.852447       91.763735
# min         0.000000       0.000000     -45.302000        0.568000
# ...
